# %% [markdown]
# Робив на основі - https://github.com/KharchenkoV/geo/tree/master/lab7

# %%
import geopandas
import rasterio
from rasterio.mask import mask
import glob
import os

field_polygons = geopandas.read_file('./field_polygons.geojson')
field_polygons['Name'] = field_polygons['Name'] + '_' +  str(field_polygons.index)
field_polygons
# Out:
#     id                                            Name
# 0    1       Pin4_RangeIndex(start=0, stop=44, step=1)  \
# 1    2      Pin17_RangeIndex(start=0, stop=44, step=1)
# 2    3  Shev7-8-9_RangeIndex(start=0, stop=44, step=1)
# 3    4     Shev10_RangeIndex(start=0, stop=44, step=1)
# 4    5        Tr5_RangeIndex(start=0, stop=44, step=1)
# 5    6      Shev6_RangeIndex(start=0, stop=44, step=1)
# 6    7        Tr4_RangeIndex(start=0, stop=44, step=1)
# 7    8        Tr3_RangeIndex(start=0, stop=44, step=1)
# 8    9        Tr2_RangeIndex(start=0, stop=44, step=1)
# 9   10       Tr10_RangeIndex(start=0, stop=44, step=1)
# 10  11        Tr9_RangeIndex(start=0, stop=44, step=1)
# 11  12      Shev4_RangeIndex(start=0, stop=44, step=1)
# 12  13        Tr1_RangeIndex(start=0, stop=44, step=1)
# 13  14        Tr2_RangeIndex(start=0, stop=44, step=1)
# 14  15     Yatz50_RangeIndex(start=0, stop=44, step=1)
# 15  16  Yatz220/1_RangeIndex(start=0, stop=44, step=1)
# 16  17  Yatz220/2_RangeIndex(start=0, stop=44, step=1)
# 17  18     Yatz36_RangeIndex(start=0, stop=44, step=1)
# 18  18     Yatz60_RangeIndex(start=0, stop=44, step=1)
# 19  19     Yatz45_RangeIndex(start=0, stop=44, step=1)
# 20  21     Yatz44_RangeIndex(start=0, stop=44, step=1)
# 21  22        Ks8_RangeIndex(start=0, stop=44, step=1)
# 22  23       Pin9_RangeIndex(start=0, stop=44, step=1)
# 23  24        Ks1_RangeIndex(start=0, stop=44, step=1)
# 24  25        Ks5_RangeIndex(start=0, stop=44, step=1)
# 25  27     Pin9/1_RangeIndex(start=0, stop=44, step=1)
# 26  27      pin10_RangeIndex(start=0, stop=44, step=1)
# 27  29      Shev3_RangeIndex(start=0, stop=44, step=1)
# 28  30      Shev2_RangeIndex(start=0, stop=44, step=1)
# 29  31      Shev1_RangeIndex(start=0, stop=44, step=1)
# 30  32       Ks11_RangeIndex(start=0, stop=44, step=1)
# 31  32        Ks6_RangeIndex(start=0, stop=44, step=1)
# 32  34        Ks7_RangeIndex(start=0, stop=44, step=1)
# 33  36        Tr6_RangeIndex(start=0, stop=44, step=1)
# 34  36       Tr10_RangeIndex(start=0, stop=44, step=1)
# 35  38        Tr8_RangeIndex(start=0, stop=44, step=1)
# 36  38        Tr8_RangeIndex(start=0, stop=44, step=1)
# 37  39        Tr7_RangeIndex(start=0, stop=44, step=1)
# 38  40      Tr7/1_RangeIndex(start=0, stop=44, step=1)
# 39  41        Ls3_RangeIndex(start=0, stop=44, step=1)
# 40  42        Ks2_RangeIndex(start=0, stop=44, step=1)
# 41  42       Ks15_RangeIndex(start=0, stop=44, step=1)
# 42  82       Ks12_RangeIndex(start=0, stop=44, step=1)
# 43  83       Ks13_RangeIndex(start=0, stop=44, step=1)
#
#                                              geometry
# 0   MULTIPOLYGON (((30.17411 49.99641, 30.17705 50...
# 1   MULTIPOLYGON (((30.24050 49.98769, 30.24404 49...
# 2   MULTIPOLYGON (((30.32204 50.00902, 30.33148 50...
# 3   MULTIPOLYGON (((30.35295 50.01389, 30.35007 50...
# 4   MULTIPOLYGON (((30.33304 50.02297, 30.34076 50...
# 5   MULTIPOLYGON (((30.31524 50.02392, 30.31583 50...
# 6   MULTIPOLYGON (((30.34083 50.03253, 30.34986 50...
# 7   MULTIPOLYGON (((30.36117 50.04025, 30.36097 50...
# 8   MULTIPOLYGON (((30.35835 50.04439, 30.35962 50...
# 9   MULTIPOLYGON (((30.33419 50.02495, 30.32681 50...
# 10  MULTIPOLYGON (((30.31089 50.02778, 30.30300 50...
# 11  MULTIPOLYGON (((30.31077 50.02776, 30.30801 50...
# 12  MULTIPOLYGON (((30.37998 50.08080, 30.36923 50...
# 13  MULTIPOLYGON (((30.36943 50.06676, 30.38037 50...
# 14  MULTIPOLYGON (((30.41260 50.03523, 30.41305 50...
# 15  MULTIPOLYGON (((30.41584 50.02548, 30.42128 50...
# 16  MULTIPOLYGON (((30.42718 50.02542, 30.43065 50...
# 17  MULTIPOLYGON (((30.43968 50.02555, 30.44269 50...
# 18  MULTIPOLYGON (((30.44707 50.02517, 30.46051 50...
# 19  MULTIPOLYGON (((30.42709 50.01402, 30.42824 50...
# 20  MULTIPOLYGON (((30.39190 50.00432, 30.39223 50...
# 21  MULTIPOLYGON (((30.22781 50.03749, 30.22894 50...
# 22  MULTIPOLYGON (((30.23693 50.02784, 30.23850 50...
# 23  MULTIPOLYGON (((30.20194 50.06182, 30.20723 50...
# 24  MULTIPOLYGON (((30.21809 50.06222, 30.21884 50...
# 25  MULTIPOLYGON (((30.24865 50.01706, 30.25114 50...
# 26  MULTIPOLYGON (((30.25749 50.02448, 30.25792 50...
# 27  MULTIPOLYGON (((30.29413 50.03381, 30.29123 50...
# 28  MULTIPOLYGON (((30.29122 50.03751, 30.28684 50...
# 29  MULTIPOLYGON (((30.28146 50.04754, 30.28363 50...
# 30  MULTIPOLYGON (((30.25310 50.04018, 30.25364 50...
# 31  MULTIPOLYGON (((30.24975 50.04569, 30.25688 50...
# 32  MULTIPOLYGON (((30.23020 50.03950, 30.22977 50...
# 33  MULTIPOLYGON (((30.32902 50.03971, 30.32901 50...
# 34  MULTIPOLYGON (((30.32707 50.04034, 30.31133 50...
# 35  MULTIPOLYGON (((30.32468 50.06402, 30.32409 50...
# 36  MULTIPOLYGON (((30.32404 50.05966, 30.32734 50...
# 37  MULTIPOLYGON (((30.32526 50.06256, 30.32929 50...
# 38  MULTIPOLYGON (((30.33510 50.06376, 30.33659 50...
# 39  MULTIPOLYGON (((30.18921 50.02613, 30.18954 50...
# 40  MULTIPOLYGON (((30.20297 50.02709, 30.20629 50...
# 41  MULTIPOLYGON (((30.23337 50.03033, 30.23604 50...
# 42  MULTIPOLYGON (((30.23290 50.03060, 30.23140 50...
# 43  MULTIPOLYGON (((30.21842 50.03580, 30.22176 50...

# %%
len(glob.glob('./spatial_data/**/*.tif'))
# Out:
# 68

# %%
if not os.path.exists('./resampled'):
    os.mkdir('./resampled')

for name in field_polygons['Name']:
    if ('/' in name):
        name = name.replace('/', '_')
    dir_name = os.path.join('./resampled', name)
    if not os.path.exists(dir_name):
        os.makedirs(dir_name)

# %%
list_spatial_path = './spatial_data'
list_spatial_data = [f for f in os.listdir(list_spatial_path) if os.path.isdir(os.path.join(list_spatial_path, f))]

for index, row in field_polygons.iterrows():
    geometry = row['geometry']
    name = row['Name']

    for spatial_data_folder in list_spatial_data:
        spatial_data_file_name = os.listdir(os.path.join(list_spatial_path, spatial_data_folder))[0]
        spatial_data_file_path = os.path.join(list_spatial_path, os.path.join(spatial_data_folder, spatial_data_file_name))

        spatial_data_file = rasterio.open(spatial_data_file_path)
        cropped_spatial_data, cropped_spatial_transform = mask(spatial_data_file, shapes=[geometry], crop=True)

        out_meta = spatial_data_file.meta.copy()
        out_meta.update({"driver": "GTiff",
            "height": cropped_spatial_data.shape[1],
            "width": cropped_spatial_data.shape[2],
            "transform": cropped_spatial_transform})
        
        if ('/' in name):
            name = name.replace('/', '_')

        out_folder_path = os.path.join(os.path.join('./resampled', name), spatial_data_folder)
        out_file_path = os.path.join(out_folder_path, spatial_data_file_name)
        if not os.path.exists(out_folder_path):
            os.mkdir(out_folder_path)

        with rasterio.open(out_file_path, 'w', **out_meta) as f:
            f.write(cropped_spatial_data)
